# %%
import matplotlib.pyplot as plt

# %%
x=[3,4,5]
y=[3,4,5]
x2=[3,4,5,6]
y2=[3,4,6,6]
plt.bar(x2,y2,label='time',color='r')
plt.bar(x,y,label='getjob',color='k')
plt.xlabel('bharat')
plt.ylabel('Chavhan')
plt.title('job')
plt.legend()

# %%
import cufflinks as cf

# %%
df=cf.datagen.lines()#taking random values
df
# Out:
#               LVV.VF     KQX.SQ    SHG.UW    DVT.OO    DXP.UT
# 2015-01-01 -0.220841   2.041582 -1.616866  0.011085  0.653156
# 2015-01-02 -1.807641   2.670352 -2.205320 -0.527904  1.683226
# 2015-01-03 -2.279749   1.471163 -3.895763  0.601737  3.686213
# 2015-01-04 -2.105474   3.079657 -3.809537 -0.418715  3.224517
# 2015-01-05 -2.147957   1.833246 -1.629312 -0.879514  2.879361
# ...              ...        ...       ...       ...       ...
# 2015-04-06 -5.656508  -9.043658 -4.054101  6.600078  4.846496
# 2015-04-07 -6.435633  -9.279718 -4.678655  6.941561  5.167110
# 2015-04-08 -6.580756 -11.121737 -2.872498  8.381369  5.244926
# 2015-04-09 -4.179718 -11.006376 -3.274205  9.858640  4.721061
# 2015-04-10 -5.617341 -10.791145 -3.083210  9.229843  4.880022
#
# [100 rows x 5 columns]

# %%
import seaborn as sns

# %%
a=sns.load_dataset("flights")
sns.relplot(x="passengers",y="month",hue='year' ,data=a)

# %%
b=sns.load_dataset("tips")
sns.relplot(x="time",y="tip",data=a ,kind="line")

# %%
sns.catplot
# Out:
# <function seaborn.categorical.catplot(x=None, y=None, hue=None, data=None, row=None, col=None, col_wrap=None, estimator=<function mean at 0x00000201B8EBF8B8>, ci=95, n_boot=1000, units=None, order=None, hue_order=None, row_order=None, col_order=None, kind='strip', height=5, aspect=1, orient=None, color=None, palette=None, legend=True, legend_out=True, sharex=True, sharey=True, margin_titles=False, facet_kws=None, **kwargs)>

# %%
sns.catplot(x='day',y='total_bill',data=b)

# %%
sns.catplot(x='day',y='total_bill',data=b,kind='box')

# %%
sns.catplot(x='day',y='total_bill',data=b,kind='violin')

# %%
sns.catplot(x='day',y='total_bill',data=b,kind="boxen")

# %%
from scipy import stats
import numpy as np

# %%
c=np.random.normal(loc=5,size=100,scale=2)
sns.distplot(c)

# %%
a=sns.load_dataset("flights")
b=sns.PairGrid(a)
b.map(plt.scatter)

# %%
sns.set(style='dark')
a=sns.load_dataset("iris")
b=sns.FacetGrid(a,col='species')
b.map(plt.hist,'sepal_length')
